# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# C:\Users\DELL\Documents\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
string="""2.5,21,5.1,47,3.2,27,8.5,75,3.5,30,1.5,20,9.2,88,5.5,60,8.3,81,2.7,25,7.7,85,5.9,62,4.5,41,3.3,42,1.1,17,8.9,95,2.5,30,1.9,24,6.1,67,7.4,69,2.7,30,4.8,54,3.8,35,6.9,76,7.8,86"""

result = string.split(',')
dic={"Hours":result[::2],"Scores":result[1::2]}

df=pd.DataFrame(dic)

df["Hours"]=df["Hours"].astype(float)
df["Scores"]=df["Scores"].astype(int)
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression(fit_intercept=True)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
line_equ=model.coef_*x +model.intercept_
plt.scatter(x, y)
plt.plot(x, line_equ,c="r");
plt.show()

# %%
y_pred = model.predict(x_test)
compare =pd.DataFrame({"Actual":y_test,"prediction":y_pred})
compare
# Out:
# C:\Users\DELL\Documents\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#    Actual  prediction
# 0      20   16.884145
# 1      27   33.732261
# 2      69   75.357018
# 3      30   26.794801
# 4      62   60.491033

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002975

# %%
# what will be the output when x = 9.5
hour=np.array([[9.5]])
sing_pred=model.predict(hour)
print(f"When x = 9.5 output is {sing_pred[0]}")
# Out:
# When x = 9.5 output is 96.16939660753593
# C:\Users\DELL\Documents\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
